# %%
import sys

if sys.platform == "emscripten":
    import piplite
    await piplite.install("nmrpaint==0.1.0")

from IPython.display import display
from nmrpaint import create_app

display(create_app())
